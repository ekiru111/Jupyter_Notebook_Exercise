# %% [markdown]
# # Calling libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing data

# %%
Data = pd.read_csv("D:/Projects/RoseMary/Research project/Rehospitalization2.csv")

# %%
# This shows the data types and other information
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 49 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Patient_ID                                          778 non-null    int64
#  1   Age                                                 778 non-null    int64
#  2   Gender                                              778 non-null    object
#  3   Marital_status                                      778 non-null    object
#  4   Occupation                                          778 non-null    object
#  5   Residence                                           778 non-null    object
#  6   Education_level                                     726 non-null    object
#  7   Region                                              778 non-null    object
# ...

# %%
# Checking the dimensions of the dataset
Data.shape
# Out:
# (778, 49)

# %%
Data['Age'].describe()
# Out:
# count    778.000000
# mean      31.349614
# std       11.031423
# min       16.000000
# 25%       23.000000
# 50%       29.000000
# 75%       37.000000
# max       99.000000
# Name: Age, dtype: float64

# %%
Data["Age"].agg(["mean", "std"])
# Out:
# mean    31.349614
# std     11.031423
# Name: Age, dtype: float64

# %%
Data["Gender"].value_counts(normalize=False)
# Out:
# Gender
# Male      498
# Female    280
# Name: count, dtype: int64

# %%
Data.columns
# Out:
# Index(['Patient_ID ', 'Age', 'Gender', 'Marital_status', 'Occupation',
#        'Residence', 'Education_level', 'Region',
#        'family_member_present_on_admission', 'Relationship_with_next_of_kin',
#        'Primary_Psychiatric_Diagnosis', 'Other', 'Comorbid_medical_conditions',
#        'Comorbid_substance_use', 'If_yes ', 'Duration_illness_(in years)',
#        'Previous_mental_health_hospitalizations', 'Medication_adherence',
#        'Type_of_medication_prescribed', 'Antipsychotics_medication_prescribed',
#        'Mood_stabilizers_medication_prescribed',
#        'Antidepressants_medication_prescribed',
#        'Missing_medication_prescribed', 'History_of_suicide_attempts',
#        'If_yes_how_many_times', 'History_of_violence_or_aggression',
#        'History_of_head_injury', 'History_of_convulsions ',
#        'Stigma_experienced ', 'Date_of_index_admission', 'Date_of_discharge',
#        'Length_of_hospitalization_days', 'Reason_for_admission', 'Other.1',
# ...

# %%
Data.loc[500:505]
# Out:
#      Patient_ID   Age  Gender Marital_status  Occupation    Residence  \
# 500       102104   38    Male        Married  Unemployed  Outside KMP
# 501       102123   36    Male       Divorced  Unemployed          KMP
# 502       102247   37    Male        Married     Unknown  Outside KMP
# 503       102124   37  Female        Married     Unknown          KMP
# 504       102264   32  Female        Married     Unknown          KMP
# 505       102262   26  Female        Married    Employed          KMP
#
#     Education_level       Region family_member_present_on_admission  \
# 500             NaN  Non Ugandan                                 No
# 501             NaN      Central                                Yes
# 502         Unknown      Eastern                                Yes
# 503       Secondary      Central                                 No
# 504       Secondary      Central                                Yes
# ...

# %%
Data.iloc[0]
# Out:
# Patient_ID                                                                    78470
# Age                                                                              35
# Gender                                                                         Male
# Marital_status                                                              Married
# Occupation                                                                 Employed
# Residence                                                               Outside KMP
# Education_level                                                            Tertiary
# Region                                                                      Eastern
# family_member_present_on_admission                                              Yes
# Relationship_with_next_of_kin                                         Family member
# Primary_Psychiatric_Diagnosis                                Substance use disorder
# ...

# %%
# view the first 5 entries
Data.head()
# Out:
#    Patient_ID   Age Gender Marital_status  Occupation    Residence  \
# 0        78470   35   Male        Married    Employed  Outside KMP
# 1        98077   18   Male         Single  Unemployed  Outside KMP
# 2        92284   19   Male         Single     Student          KMP
# 3        92320   22   Male        Married    Employed  Outside KMP
# 4        92319   48   Male         Single  Unemployed  Outside KMP
#
#   Education_level       Region family_member_present_on_admission  \
# 0        Tertiary      Eastern                                Yes
# 1       Secondary      Western                                Yes
# 2       Secondary      Eastern                                Yes
# 3             NaN      Central                                Yes
# 4             NaN  Non Ugandan                                 No
#
#   Relationship_with_next_of_kin  ... Review_date Rehospitalization_status  \
# 0                 Family member  ...  2025-05-21                       No
# ...
